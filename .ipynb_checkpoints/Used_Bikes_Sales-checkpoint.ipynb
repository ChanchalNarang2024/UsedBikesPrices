# %% [markdown]
# ## Used Bikes-Feature Engineering and EDA

# %% [markdown]
# ### Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %% [markdown]
# ### Data collection and reading Dataset

# %%
Bikes_Sales_Data=pd.read_csv('bikes.csv')
Bikes_Sales_Data
# Out:
#                             model_name  model_year       kms_driven  \
# 0        Bajaj Avenger Cruise 220 2017        2017         17000 Km
# 1     Royal Enfield Classic 350cc 2016        2016         50000 Km
# 2                  Hyosung GT250R 2012        2012         14795 Km
# 3           Bajaj Dominar 400 ABS 2017        2017   Mileage 28 Kms
# 4                Jawa Perak 330cc 2020        2020          2000 Km
# ...                                ...         ...              ...
# 7852         Yamaha YZF-R15 150cc 2011        2011          7000 Km
# 7853         Bajaj Discover 100cc 2015        2015  Mileage 80 Kmpl
# 7854           Bajaj Pulsar 180cc 2016        2016          6407 Km
# 7855              Bajaj V15 150cc 2016        2016          7524 Km
# 7856           Bajaj Pulsar 220cc 2016        2016         15000 Km
#
#             owner     location       mileage      power   price
# 0     first owner    hyderabad  \n\n 35 kmpl     19 bhp   63500
# 1     first owner    hyderabad  \n\n 35 kmpl  19.80 bhp  115000
# 2     first owner    hyderabad  \n\n 30 kmpl     28 bhp  300000
# 3     first owner  pondicherry   \n\n 28 Kms  34.50 bhp  100000
# 4     first owner    bangalore         \n\n      30 bhp  197500
# ...           ...          ...           ...        ...     ...
# 7852  first owner         agra  \n\n 42 kmpl     16 bhp   55000
# 7853  first owner        delhi  \n\n 80 Kmpl        7.7   28000
# 7854  first owner    bangalore  \n\n 65 kmpl     17 bhp   61740
# 7855  first owner    bangalore  \n\n 57 kmpl  11.80 bhp   49000
# 7856  first owner      chennai  \n\n 38 kmpl     21 bhp   65000
#
# [7857 rows x 8 columns]

# %% [markdown]
# ### Creating DataFrame

# %%
Bikes_Sales_DF=pd.DataFrame(Bikes_Sales_Data)

# %% [markdown]
# ### Displaying First 5 rows of Dataframe

# %%
Bikes_Sales_DF.head()
# Out:
#                          model_name  model_year      kms_driven        owner  \
# 0     Bajaj Avenger Cruise 220 2017        2017        17000 Km  first owner
# 1  Royal Enfield Classic 350cc 2016        2016        50000 Km  first owner
# 2               Hyosung GT250R 2012        2012        14795 Km  first owner
# 3        Bajaj Dominar 400 ABS 2017        2017  Mileage 28 Kms  first owner
# 4             Jawa Perak 330cc 2020        2020         2000 Km  first owner
#
#       location       mileage      power   price
# 0    hyderabad  \n\n 35 kmpl     19 bhp   63500
# 1    hyderabad  \n\n 35 kmpl  19.80 bhp  115000
# 2    hyderabad  \n\n 30 kmpl     28 bhp  300000
# 3  pondicherry   \n\n 28 Kms  34.50 bhp  100000
# 4    bangalore         \n\n      30 bhp  197500

# %% [markdown]
# ### Displaying last 5 rows of Dataframe

# %%
 Bikes_Sales_DF.tail()
# Out:
#                      model_name  model_year       kms_driven        owner  \
# 7852  Yamaha YZF-R15 150cc 2011        2011          7000 Km  first owner
# 7853  Bajaj Discover 100cc 2015        2015  Mileage 80 Kmpl  first owner
# 7854    Bajaj Pulsar 180cc 2016        2016          6407 Km  first owner
# 7855       Bajaj V15 150cc 2016        2016          7524 Km  first owner
# 7856    Bajaj Pulsar 220cc 2016        2016         15000 Km  first owner
#
#        location       mileage      power  price
# 7852       agra  \n\n 42 kmpl     16 bhp  55000
# 7853      delhi  \n\n 80 Kmpl        7.7  28000
# 7854  bangalore  \n\n 65 kmpl     17 bhp  61740
# 7855  bangalore  \n\n 57 kmpl  11.80 bhp  49000
# 7856    chennai  \n\n 38 kmpl     21 bhp  65000

# %% [markdown]
# ### Data information

# %%
Bikes_Sales_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7857 entries, 0 to 7856
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   model_name  7857 non-null   object
#  1   model_year  7857 non-null   int64
#  2   kms_driven  7857 non-null   object
#  3   owner       7857 non-null   object
#  4   location    7838 non-null   object
#  5   mileage     7846 non-null   object
#  6   power       7826 non-null   object
#  7   price       7857 non-null   int64
# dtypes: int64(2), object(6)
# memory usage: 491.2+ KB

# %% [markdown]
# ### Stastical information about Data

# %%
Bikes_Sales_DF.describe()
# Out:
#         model_year         price
# count  7857.000000  7.857000e+03
# mean   2015.367698  1.067913e+05
# std       4.001443  1.389261e+05
# min    1950.000000  0.000000e+00
# 25%    2014.000000  4.200000e+04
# 50%    2016.000000  7.500000e+04
# 75%    2018.000000  1.250000e+05
# max    2021.000000  3.000000e+06

# %% [markdown]
# ### Missing values check

# %%
Bikes_Sales_DF.isna().sum()
# Out:
# model_name     0
# model_year     0
# kms_driven     0
# owner          0
# location      19
# mileage       11
# power         31
# price          0
# dtype: int64

# %% [markdown]
# ### Dropping missing values

# %%
Bikes_Sales_DF=Bikes_Sales_DF.dropna()

# %%
Bikes_Sales_DF.isna().sum()   # All missing values removed
# Out:
# model_name    0
# model_year    0
# kms_driven    0
# owner         0
# location      0
# mileage       0
# power         0
# price         0
# dtype: int64

# %%
Bikes_Sales_DF.sort_values(by=['model_year']) # Sorted Dataframe by Bikes model_year
# Out:
#                                              model_name  model_year  \
# 2211                         Bajaj Pulsar NS 200cc 2013        1950
# 4258                         Bajaj Pulsar NS 200cc 2013        1950
# 3429                   Royal Enfield‎ Bullet 350cc 1970        1970
# 4174                  Royal Enfield Standard 350cc 1985        1985
# 5584                         Yazdi Road King 250cc 1986        1986
# ...                                                 ...         ...
# 2741               Hero Passion Pro 110cc Drum BS6 2021        2021
# 709   Royal Enfield Classic 350cc ABS Stealth Black ...        2021
# 710                          Hero Xpulse 200cc BS6 2021        2021
# 2267                        Yamaha MT-15 150cc BS6 2021        2021
# 307                             KTM Duke 125cc BS6 2021        2021
#
#            kms_driven        owner    location          mileage  \
# 2211  Mileage 35 Kmpl  first owner       noida     \n\n 35 Kmpl
# 4258  Mileage 35 Kmpl  third owner  khalilabad     \n\n 35 Kmpl
# 3429          5000 Km  third owner        pune     \n\n 25 kmpl
# 4174  Mileage 40 Kmpl  third owner    kolhapur     \n\n 40 Kmpl
# 5584        100000 Km  first owner     lucknow            \n\n
# ...               ...          ...         ...              ...
# 2741           236 Km  first owner        pune            \n\n
# 709           2002 Km  first owner   hyderabad     \n\n 35 kmpl
# 710            628 Km  first owner     gwalior  \n\n 46.40 kmpl
# 2267          3000 Km  first owner   bangalore            \n\n
# 307           3800 Km  first owner        jind            \n\n
#
#                    power   price
# 2211           23.19 bhp   55000
# 4258           23.19 bhp   55000
# 3429           19.80 bhp  190000
# 4174              18 bhp  125000
# 5584  16 BHP at 5000 rpm   60000
# ...                  ...     ...
# 2741            9.02 bhp   80000
# 709             19.1 bhp  220000
# 710             17.8 bhp  110000
# 2267           18.23 bhp  180000
# 307             14.3 bhp  175000
#
# [7796 rows x 8 columns]

# %% [markdown]
# ### Outlier Check for Target Variable
# #### Box Plot

# %%
x=Bikes_Sales_DF['price']
plt.ticklabel_format(style='plain')
plt.boxplot(x)
plt.show()

# %% [markdown]
# ### outliers removed for Target Variable i.e. Price

# %%
Bikes_Sales_DF=Bikes_Sales_DF[Bikes_Sales_DF['price']<200000]
x=Bikes_Sales_DF['price']
plt.ticklabel_format(style='plain')
plt.boxplot(x)
plt.ylabel('price')
plt.show()

# %% [markdown]
# ### Bar Graph between model_year and Price

# %%
x=Bikes_Sales_DF['model_year']
y=Bikes_Sales_DF['price']
plt.ticklabel_format(style='plain')
plt.bar(x,y)
plt.xlabel('model_year')
plt.ylabel('price')
plt.title('model_year vs price')
plt.ticklabel_format(style='plain') # to remove le6
plt.show()

# %% [markdown]
# #### Conclusion
# - **Maximum Sales came from Bikes having model_year in range 2010 to 2020**
# - **Very Few were interested in bikes whose model_year is older than 1970**

# %%
Bikes_Sales_DF
# Out:
#                             model_name  model_year       kms_driven  \
# 0        Bajaj Avenger Cruise 220 2017        2017         17000 Km
# 1     Royal Enfield Classic 350cc 2016        2016         50000 Km
# 3           Bajaj Dominar 400 ABS 2017        2017   Mileage 28 Kms
# 4                Jawa Perak 330cc 2020        2020          2000 Km
# 5                  KTM Duke 200cc 2012        2012         24561 Km
# ...                                ...         ...              ...
# 7852         Yamaha YZF-R15 150cc 2011        2011          7000 Km
# 7853         Bajaj Discover 100cc 2015        2015  Mileage 80 Kmpl
# 7854           Bajaj Pulsar 180cc 2016        2016          6407 Km
# 7855              Bajaj V15 150cc 2016        2016          7524 Km
# 7856           Bajaj Pulsar 220cc 2016        2016         15000 Km
#
#             owner     location       mileage      power   price
# 0     first owner    hyderabad  \n\n 35 kmpl     19 bhp   63500
# 1     first owner    hyderabad  \n\n 35 kmpl  19.80 bhp  115000
# 3     first owner  pondicherry   \n\n 28 Kms  34.50 bhp  100000
# 4     first owner    bangalore         \n\n      30 bhp  197500
# 5     third owner    bangalore  \n\n 35 kmpl     25 bhp   63400
# ...           ...          ...           ...        ...     ...
# 7852  first owner         agra  \n\n 42 kmpl     16 bhp   55000
# 7853  first owner        delhi  \n\n 80 Kmpl        7.7   28000
# 7854  first owner    bangalore  \n\n 65 kmpl     17 bhp   61740
# 7855  first owner    bangalore  \n\n 57 kmpl  11.80 bhp   49000
# 7856  first owner      chennai  \n\n 38 kmpl     21 bhp   65000
#
# [7190 rows x 8 columns]

# %%
Bikes_Sales_DF['model_name'].value_counts()   # Checking count of each bikes
# Out:
# model_name
# Royal Enfield Classic 350cc 2017            78
# Royal Enfield Classic 350cc 2016            69
# Royal Enfield Classic 350cc 2015            67
# Royal Enfield Thunderbird 350cc 2015        63
# Royal Enfield Classic 350cc 2018            59
#                                             ..
# Bajaj Avenger Street 160 ABS FI BS6 2021     1
# Jawa Forty Two 295CC Dual ABS BS6 2021       1
# KTM Duke 390cc 2019                          1
# Suzuki Hayate 110cc 2009                     1
# Hero CD Deluxe 100cc 2004                    1
# Name: count, Length: 1471, dtype: int64

# %% [markdown]
# ### conclusion
# - From above value,i found that model_name **Royal Enfield Classic 350cc 2017** sold the most
# - **Major Revenue came from this model**
